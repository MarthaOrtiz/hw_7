# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
datos= loadtxt('resultados.txt',delimiter=',')

# %%
datos
# Out:
# array([[  4.99999900e+00,   8.66025400e+00,   8.66030000e-02,
#          -5.00000000e-02],
#        [  8.66025300e+00,   5.00000200e+00,   5.00000000e-02,
#          -8.66030000e-02],
#        [  1.00000000e+01,   3.00000000e-06,   0.00000000e+00,
#          -1.00000000e-01],
#        [  8.66025600e+00,  -4.99999600e+00,  -5.00000000e-02,
#          -8.66030000e-02],
#        [  5.00000500e+00,  -8.66025200e+00,  -8.66030000e-02,
#          -5.00000000e-02],
#        [  7.00000000e-06,  -1.00000000e+01,  -1.00000000e-01,
#          -0.00000000e+00],
#        [ -4.99999300e+00,  -8.66025800e+00,  -8.66030000e-02,
#           5.00000000e-02],
#        [ -8.66025000e+00,  -5.00000800e+00,  -5.00000000e-02,
#           8.66020000e-02],
#        [ -1.00000000e+01,  -1.00000000e-05,  -0.00000000e+00,
#           1.00000000e-01],
#        [ -8.66025900e+00,   4.99999000e+00,   5.00000000e-02,
#           8.66030000e-02],
#        [ -5.00001000e+00,   8.66024800e+00,   8.66020000e-02,
# ...

# %%
plot(datos[:,0],datos[:,1],'ko')

# %%
plot(datos
# Out:
# [43.30138]
